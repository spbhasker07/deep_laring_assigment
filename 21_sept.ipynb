# %%
import pandas as pd
import numpy as np
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S,preprocess_input,decode_predictions
import tensorflow as tf
import random

# %%
model=EfficientNetV2S()
# Out:
# ...
# 87549136/87549136 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetv2-s"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 384, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 384, 384,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 192, 192,  │        648 │ rescaling[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras.preprocessing.image import load_img,img_to_array

# %%
img=img_to_array(load_img('horse.jp',target_size=(384,384),color_mode='rgb'))
img=preprocess_input(img.reshape(1,384,384,3))
probs=model.predict(img)
decode_predictions(probs,top=3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# [[('n02669723', 'academic_gown', np.float32(0.07330716)),
#   ('n04456115', 'torch', np.float32(0.04514736)),
#   ('n03942813', 'ping-pong_ball', np.float32(0.04478081))]]
