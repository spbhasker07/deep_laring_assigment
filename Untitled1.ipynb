# %%
import tensorflow as tf

# %%
model=tf.keras.models.load_model('gender(1).keras')
model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model=tf.keras.models.load_model('gender(1).keras')
#       2 model
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     186         is_keras_zip = True
#     188 if is_keras_zip or is_keras_dir or is_hf:
# --> 189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#
# ...
